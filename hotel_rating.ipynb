# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('reviews.csv')

# %%
df
# Out:
#        review_id  user_id  hotel_id review_date  score_overall  \
# 0              1     1600         1  2022-10-07            8.7
# 1              2      432         4  2020-03-24            9.1
# 2              3      186        18  2023-12-18            8.8
# 3              4     1403        19  2022-06-22            8.9
# 4              5     1723        17  2022-07-02            9.1
# ...          ...      ...       ...         ...            ...
# 49995      49996     1786        24  2022-08-07            8.4
# 49996      49997     1739         8  2025-03-05            8.8
# 49997      49998     1566         6  2025-05-03            9.1
# 49998      49999       10        21  2024-09-27            9.0
# 49999      50000     1626        19  2022-02-09            9.2
#
#        score_cleanliness  score_comfort  score_facilities  score_location  \
# 0                    8.6            8.7               8.5             9.0
# 1                   10.0            9.1               9.0             8.6
# 2                    9.7            8.8               8.3             8.7
# 3                    9.0            8.8               8.5             9.6
# 4                    8.9            9.5               9.3             8.3
# ...                  ...            ...               ...             ...
# 49995                8.2            8.2               8.5             9.1
# 49996                8.8            9.0               8.0             9.5
# 49997                9.8            9.1               8.5             9.6
# 49998                8.7            9.1               8.7             9.7
# 49999                9.7            9.4               9.0             9.5
#
#        score_staff  score_value_for_money  \
# 0              8.8                    8.7
# 1              9.4                    8.6
# 2              8.1                    8.6
# 3              9.1                    8.3
# 4              9.4                    8.9
# ...            ...                    ...
# 49995          8.3                    7.5
# 49996          8.8                    8.7
# 49997          9.3                    8.0
# 49998          9.0                    8.7
# 49999          8.9                    8.8
#
#                                              review_text
# 0      Practice reduce young our because machine. Rec...
# 1      Test cover traditional black. Process tell Mr ...
# 2      Friend million student social study yeah. Grow...
# 3      Huge girl already remain truth behind card. Ap...
# 4      Cover feeling call community serve television ...
# ...                                                  ...
# 49995  Thing her against garden method magazine. Inte...
# 49996  But benefit away major. Story kid often offici...
# 49997  But certainly part special moment certain buil...
# 49998  Ask suffer space return. Hospital material the...
# 49999  Story student tax various. Child whole only ch...
#
# [50000 rows x 12 columns]

# %%
df.head()
# Out:
#    review_id  user_id  hotel_id review_date  score_overall  score_cleanliness  \
# 0          1     1600         1  2022-10-07            8.7                8.6
# 1          2      432         4  2020-03-24            9.1               10.0
# 2          3      186        18  2023-12-18            8.8                9.7
# 3          4     1403        19  2022-06-22            8.9                9.0
# 4          5     1723        17  2022-07-02            9.1                8.9
#
#    score_comfort  score_facilities  score_location  score_staff  \
# 0            8.7               8.5             9.0          8.8
# 1            9.1               9.0             8.6          9.4
# 2            8.8               8.3             8.7          8.1
# 3            8.8               8.5             9.6          9.1
# 4            9.5               9.3             8.3          9.4
#
#    score_value_for_money                                        review_text
# 0                    8.7  Practice reduce young our because machine. Rec...
# 1                    8.6  Test cover traditional black. Process tell Mr ...
# 2                    8.6  Friend million student social study yeah. Grow...
# 3                    8.3  Huge girl already remain truth behind card. Ap...
# 4                    8.9  Cover feeling call community serve television ...

# %%
df.columns
# Out:
# Index(['review_id', 'user_id', 'hotel_id', 'review_date', 'score_overall',
#        'score_cleanliness', 'score_comfort', 'score_facilities',
#        'score_location', 'score_staff', 'score_value_for_money',
#        'review_text'],
#       dtype='object')

# %%
df.describe()
# Out:
#           review_id       user_id      hotel_id  score_overall  \
# count  50000.000000  50000.000000  50000.000000   50000.000000
# mean   25000.500000   1005.567540     13.051100       8.943460
# std    14433.901067    576.711855      7.203808       0.180878
# min        1.000000      1.000000      1.000000       8.200000
# 25%    12500.750000    507.000000      7.000000       8.800000
# 50%    25000.500000   1010.000000     13.000000       8.900000
# 75%    37500.250000   1504.000000     19.000000       9.100000
# max    50000.000000   2000.000000     25.000000       9.600000
#
#        score_cleanliness  score_comfort  score_facilities  score_location  \
# count       50000.000000   50000.000000      50000.000000    50000.000000
# mean            9.052558       9.024404          8.743062        9.176410
# std             0.504296       0.423927          0.498320        0.421086
# min             7.700000       7.900000          7.600000        7.900000
# 25%             8.700000       8.700000          8.400000        8.900000
# 50%             9.100000       9.000000          8.700000        9.200000
# 75%             9.400000       9.300000          9.100000        9.500000
# max            10.000000      10.000000         10.000000       10.000000
#
#         score_staff  score_value_for_money
# count  50000.000000           50000.000000
# mean       8.972076               8.434540
# std        0.397775               0.529321
# min        7.900000               6.800000
# 25%        8.700000               8.100000
# 50%        9.000000               8.500000
# 75%        9.200000               8.800000
# max       10.000000               9.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_id              50000 non-null  int64
#  1   user_id                50000 non-null  int64
#  2   hotel_id               50000 non-null  int64
#  3   review_date            50000 non-null  object
#  4   score_overall          50000 non-null  float64
#  5   score_cleanliness      50000 non-null  float64
#  6   score_comfort          50000 non-null  float64
#  7   score_facilities       50000 non-null  float64
#  8   score_location         50000 non-null  float64
#  9   score_staff            50000 non-null  float64
#  10  score_value_for_money  50000 non-null  float64
#  11  review_text            50000 non-null  object
# dtypes: float64(7), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df.isnull().sum()
# Out:
# review_id                0
# user_id                  0
# hotel_id                 0
# review_date              0
# score_overall            0
# score_cleanliness        0
# score_comfort            0
# score_facilities         0
# score_location           0
# score_staff              0
# score_value_for_money    0
# review_text              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_id              50000 non-null  int64
#  1   user_id                50000 non-null  int64
#  2   hotel_id               50000 non-null  int64
#  3   review_date            50000 non-null  object
#  4   score_overall          50000 non-null  float64
#  5   score_cleanliness      50000 non-null  float64
#  6   score_comfort          50000 non-null  float64
#  7   score_facilities       50000 non-null  float64
#  8   score_location         50000 non-null  float64
#  9   score_staff            50000 non-null  float64
#  10  score_value_for_money  50000 non-null  float64
#  11  review_text            50000 non-null  object
# dtypes: float64(7), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df["review_date"]=pd.to_datetime(df["review_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_id              50000 non-null  int64
#  1   user_id                50000 non-null  int64
#  2   hotel_id               50000 non-null  int64
#  3   review_date            50000 non-null  datetime64[ns]
#  4   score_overall          50000 non-null  float64
#  5   score_cleanliness      50000 non-null  float64
#  6   score_comfort          50000 non-null  float64
#  7   score_facilities       50000 non-null  float64
#  8   score_location         50000 non-null  float64
#  9   score_staff            50000 non-null  float64
#  10  score_value_for_money  50000 non-null  float64
#  11  review_text            50000 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(3), object(1)
# memory usage: 4.6+ MB

# %%
df.drop('review_text',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_id              50000 non-null  int64
#  1   user_id                50000 non-null  int64
#  2   hotel_id               50000 non-null  int64
#  3   review_date            50000 non-null  datetime64[ns]
#  4   score_overall          50000 non-null  float64
#  5   score_cleanliness      50000 non-null  float64
#  6   score_comfort          50000 non-null  float64
#  7   score_facilities       50000 non-null  float64
#  8   score_location         50000 non-null  float64
#  9   score_staff            50000 non-null  float64
#  10  score_value_for_money  50000 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(3)
# memory usage: 4.2 MB

# %%
df['review_id'].unique()
# Out:
# array([    1,     2,     3, ..., 49998, 49999, 50000], shape=(50000,))

# %%
df['review_id'].nunique()
# Out:
# 50000

# %%
df.drop('review_id',axis=1,inplace=True)

# %%
df.user_id.nunique()
# Out:
# 2000

# %%
df.tail()
# Out:
#        user_id  hotel_id review_date  score_overall  score_cleanliness  \
# 49995     1786        24  2022-08-07            8.4                8.2
# 49996     1739         8  2025-03-05            8.8                8.8
# 49997     1566         6  2025-05-03            9.1                9.8
# 49998       10        21  2024-09-27            9.0                8.7
# 49999     1626        19  2022-02-09            9.2                9.7
#
#        score_comfort  score_facilities  score_location  score_staff  \
# 49995            8.2               8.5             9.1          8.3
# 49996            9.0               8.0             9.5          8.8
# 49997            9.1               8.5             9.6          9.3
# 49998            9.1               8.7             9.7          9.0
# 49999            9.4               9.0             9.5          8.9
#
#        score_value_for_money
# 49995                    7.5
# 49996                    8.7
# 49997                    8.0
# 49998                    8.7
# 49999                    8.8

# %%
plt.figure(figsize=(10,10))
hotel_counts = df['hotel_id'].value_counts()
plt.pie(hotel_counts, labels=hotel_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Hotel IDs')
plt.axis('equal')
plt.show()

# %%
sns.countplot(x=df['review_date'].dt.year)
# Out:
# <Axes: xlabel='review_date', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
df.drop('user_id',axis=True,inplace=True)

# %%
df.head()
# Out:
#    hotel_id review_date  score_overall  score_cleanliness  score_comfort  \
# 0         1  2022-10-07            8.7                8.6            8.7
# 1         4  2020-03-24            9.1               10.0            9.1
# 2        18  2023-12-18            8.8                9.7            8.8
# 3        19  2022-06-22            8.9                9.0            8.8
# 4        17  2022-07-02            9.1                8.9            9.5
#
#    score_facilities  score_location  score_staff  score_value_for_money
# 0               8.5             9.0          8.8                    8.7
# 1               9.0             8.6          9.4                    8.6
# 2               8.3             8.7          8.1                    8.6
# 3               8.5             9.6          9.1                    8.3
# 4               9.3             8.3          9.4                    8.9

# %%
df.columns
# Out:
# Index(['hotel_id', 'review_date', 'score_overall', 'score_cleanliness',
#        'score_comfort', 'score_facilities', 'score_location', 'score_staff',
#        'score_value_for_money'],
#       dtype='object')

# %%
cols=['hotel_id', 'score_cleanliness',
       'score_comfort', 'score_facilities', 'score_location', 'score_staff',
       'score_value_for_money']

# %%
x=df[cols]
y=df['score_overall']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
import pickle
pickle.dump(sc,open('scaler.pkl','wb'))

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/anaconda3/lib/python3.13/site-packages (3.0.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from xgboost) (2.3.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.13/site-packages (from xgboost) (1.15.3)

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       4 from sklearn.tree import DecisionTreeRegressor
#       5 from sklearn.ensemble import RandomForestRegressor
# ----> 6 from xgboost import XGBRegressor
#       7 from sklearn.svm import SVR
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
base_models = [
    ('xgb', XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=1)),
    ('decision_tree', DecisionTreeRegressor(max_depth=5, random_state=1)),
    ('svm', SVR(kernel='linear'))
]


# Meta model (final estimator)
meta_model = LinearRegression()

# %%
stack=StackingRegressor(estimators=base_models,final_estimator=meta_model,cv=5)

# %%
stack
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weights=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_co...
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None, ...)),
#                               ('decision_tree',
#                                DecisionTreeRegressor(max_depth=5,
#                                                      random_state=1)),
#                               ('svm', SVR(kernel='linear'))],
#                   final_estimator=LinearRegression())

# %%
stack.fit(x_train,y_train)
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weights=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_co...
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None, ...)),
#                               ('decision_tree',
#                                DecisionTreeRegressor(max_depth=5,
#                                                      random_state=1)),
#                               ('svm', SVR(kernel='linear'))],
#                   final_estimator=LinearRegression())

# %%
y_pred=stack.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)

# %%
print(r2)
print(mse)
# Out:
# 0.9673409094971768
# 0.0010759502949175147

# %%
import pickle

# %%
with open('stack.pkl','wb') as file:
    pickle.dump(stack,file)
